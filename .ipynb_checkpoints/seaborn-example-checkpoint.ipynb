# %%
# https://therised.medium.com/visualization-with-seaborn-2-scatter-plot-joint-plot-pair-plot-a70d16456b28

# %%
import seaborn as sns

# %%
sns.set_theme(style="darkgrid")

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
ax = sns.countplot(x="class", data=titanic, hue="sex", palette="Blues")

# %%
ax = sns.histplot(data=titanic, x="age", kde=True, bins=5, hue="sex")

# %%
ax = sns.boxplot(data=titanic, x="class", y="age", hue="sex", palette="Greens")

# %%
ax = sns.scatterplot(data=titanic, x="age", y="fare", hue="alive", palette="Greens")

# %%
ax = sns.jointplot(data=titanic, x="age", y="fare", hue="alive", palette="Greens")

# %%
ax = sns.jointplot(data=titanic, x="age", y="fare", palette="Greens", kind="reg")

# %%
sns.pairplot(titanic, hue="alive")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-f8f0868d9ae2> in <module>
# ----> 1 sns.pairplot(titanic, hue="alive")
#       2 plt.show()
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2128         diag_kws.setdefault("fill", True)
#    2129         diag_kws.setdefault("warn_singular", False)
# -> 2130         grid.map_diag(kdeplot, **diag_kws)
#    2131
#    2132     # Maybe plot on the off-diagonals
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1476             plot_kwargs.setdefault("hue_order", self._hue_order)
#    1477             plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1478             func(x=vector, **plot_kwargs)
#    1479             ax.legend_ = None
#    1480
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/seaborn/distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, warn_singular, **kwargs)
#    1768             plot_kws["color"] = color
#    1769
# -> 1770         p.plot_univariate_density(
#    1771             multiple=multiple,
#    1772             common_norm=common_norm,
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/seaborn/distributions.py in plot_univariate_density(self, multiple, common_norm, common_grid, warn_singular, fill, legend, estimate_kws, **plot_kws)
#     926
#     927         # Do the computation
# --> 928         densities = self._compute_univariate_density(
#     929             self.data_variable,
#     930             common_norm,
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/seaborn/distributions.py in _compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale, warn_singular)
#     324
#     325             # Estimate the density of observations at this level
# --> 326             density, support = estimator(observations, weights=weights)
#     327
#     328             if log_scale:
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/seaborn/_statistics.py in __call__(self, x1, x2, weights)
#     185         """Fit and evaluate on univariate or bivariate data."""
#     186         if x2 is None:
# --> 187             return self._eval_univariate(x1, weights)
#     188         else:
#     189             return self._eval_bivariate(x1, x2, weights)
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/seaborn/_statistics.py in _eval_univariate(self, x, weights)
#     144         support = self.support
#     145         if support is None:
# --> 146             support = self.define_support(x, cache=False)
#     147
#     148         kde = self._fit(x, weights)
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/seaborn/_statistics.py in define_support(self, x1, x2, weights, cache)
#     117         """Create the evaluation grid for a given data set."""
#     118         if x2 is None:
# --> 119             support = self._define_support_univariate(x1, weights)
#     120         else:
#     121             support = self._define_support_bivariate(x1, x2, weights)
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/seaborn/_statistics.py in _define_support_univariate(self, x, weights)
#      89     def _define_support_univariate(self, x, weights):
#      90         """Create a 1D grid of evaluation points."""
# ---> 91         kde = self._fit(x, weights)
#      92         bw = np.sqrt(kde.covariance.squeeze())
#      93         grid = self._define_support_grid(
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/seaborn/_statistics.py in _fit(self, fit_data, weights)
#     135             fit_kws["weights"] = weights
#     136
# --> 137         kde = stats.gaussian_kde(fit_data, **fit_kws)
#     138         kde.set_bandwidth(kde.factor * self.bw_adjust)
#     139
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/scipy/stats/kde.py in __init__(self, dataset, bw_method, weights)
#     204             self._neff = 1/sum(self._weights**2)
#     205
# --> 206         self.set_bandwidth(bw_method=bw_method)
#     207
#     208     def evaluate(self, points):
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/scipy/stats/kde.py in set_bandwidth(self, bw_method)
#     552             raise ValueError(msg)
#     553
# --> 554         self._compute_covariance()
#     555
#     556     def _compute_covariance(self):
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/scipy/stats/kde.py in _compute_covariance(self)
#     564                                                bias=False,
#     565                                                aweights=self.weights))
# --> 566             self._data_inv_cov = linalg.inv(self._data_covariance)
#     567
#     568         self.covariance = self._data_covariance * self.factor**2
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/scipy/linalg/basic.py in inv(a, overwrite_a, check_finite)
#     937
#     938     """
# --> 939     a1 = _asarray_validated(a, check_finite=check_finite)
#     940     if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     941         raise ValueError('expected square matrix')
#
# /anaconda/envs/py38_default/lib/python3.8/site-packages/scipy/_lib/_util.py in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     294     if not objects_ok:
#     295         if a.dtype is np.dtype('O'):
# --> 296             raise ValueError('object arrays are not supported')
#     297     if as_inexact:
#     298         if not np.issubdtype(a.dtype, np.inexact):
#
# ValueError: object arrays are not supported
